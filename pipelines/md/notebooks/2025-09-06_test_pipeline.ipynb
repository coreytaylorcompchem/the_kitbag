# %% [markdown]
# # Testing the OpenMM pipeline

# %% [markdown]
# This notebook is to do quick checks to verify the MD pipeline is running.

# %% [markdown]
# Importing and running the code.

# %%
import sys
import os

# Go up one level from the notebook directory
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.insert(0, parent_dir)

# %%
from md import MDPipeline

workflow = MDPipeline.from_yaml("../configs/config_md.yaml")
# workflow.run()
